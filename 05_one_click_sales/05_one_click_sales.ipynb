# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span><ul class="toc-item"><li><span><a href="#Просмотр-информации-о-датафреймах" data-toc-modified-id="Просмотр-информации-о-датафреймах-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Просмотр информации о датафреймах</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-таблицы-market_file" data-toc-modified-id="Анализ-таблицы-market_file-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Анализ таблицы market_file</a></span></li><li><span><a href="#Анализ-таблицы-market_money" data-toc-modified-id="Анализ-таблицы-market_money-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Анализ таблицы market_money</a></span></li><li><span><a href="#Анализ-таблицы-market_time" data-toc-modified-id="Анализ-таблицы-market_time-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Анализ таблицы market_time</a></span></li><li><span><a href="#Анализ-таблицы-money" data-toc-modified-id="Анализ-таблицы-money-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Анализ таблицы money</a></span></li><li><span><a href="#Выводы-по-анализу-данных" data-toc-modified-id="Выводы-по-анализу-данных-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Выводы по анализу данных</a></span></li></ul></li><li><span><a href="#Объединение-таблиц" data-toc-modified-id="Объединение-таблиц-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Объединение таблиц</a></span></li><li><span><a href="#Корреляционный-анализ" data-toc-modified-id="Корреляционный-анализ-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Корреляционный анализ</a></span></li><li><span><a href="#Использование-пайплайнов" data-toc-modified-id="Использование-пайплайнов-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Использование пайплайнов</a></span></li><li><span><a href="#Анализ-важности-признаков" data-toc-modified-id="Анализ-важности-признаков-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Анализ важности признаков</a></span></li><li><span><a href="#Сегментация-покупателей" data-toc-modified-id="Сегментация-покупателей-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Сегментация покупателей</a></span></li><li><span><a href="#Общие-выводы" data-toc-modified-id="Общие-выводы-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Общие выводы</a></span></li></ul></div>

# %% [markdown]
# # Разработка модели МО для персонализированных предложений покупателям
#
# Нам передали данные о покупателях, выручке, времени покупателя на сайте, среднемесячной прибыли продавца за 3 месяца.
# Нам предоставлены следующие данные о покупателях:
#
# - id — номер покупателя в корпоративной базе данных.
# - Покупательская активность — рассчитанный класс покупательской активности (целевой признак): «снизилась» или «прежний уровень».
# - Тип сервиса — уровень сервиса, например «премиум» и «стандарт».
# - Разрешить сообщать — информация о том, можно ли присылать покупателю дополнительные предложения о товаре. Согласие на это даёт покупатель.
# - Маркет_актив_6_мес — среднемесячное значение маркетинговых коммуникаций компании, которое приходилось на покупателя за последние 6 месяцев. Это значение показывает, какое число рассылок, звонков, показов рекламы и прочего приходилось на клиента.
# - Маркет_актив_тек_мес — количество маркетинговых коммуникаций в текущем месяце.
# - Длительность — значение, которое показывает, сколько дней прошло с момента регистрации покупателя на сайте.
# - Акционные_покупки — среднемесячная доля покупок по акции от общего числа покупок за последние 6 месяцев.
# - Популярная_категория — самая популярная категория товаров у покупателя за последние 6 месяцев.
# - Средний_просмотр_категорий_за_визит — показывает, сколько в среднем категорий покупатель просмотрел за визит в течение последнего месяца.
# - Неоплаченные_продукты_штук_квартал — общее число неоплаченных товаров в корзине за последние 3 месяца.
# - Ошибка_сервиса — число сбоев, которые коснулись покупателя во время посещения сайта.
# - Страниц_за_визит — среднее количество страниц, которые просмотрел покупатель за один визит на сайт за последние 3 месяца.
#
#
#
# ***Цель исследования***:
# 1. Проанализировать полученные данные
# 2. Промаркивровать покупателей на основе уровня финансовой активности, выделив 2 категории: "снизилась", "прежний уровень"
# 3. Собрать данные по 4 группам клиентов:
# - 1) коммункация с клиентом
# - 2) продуктовое поведение
# - 3) поведение на сайте
# - 4) финансовое поведение
# 4. Построить модель модель для оценки вероятности снижения покупательской активности
# 5. Разработать персонализированные предложения для покупателей
#
# ***Ход исследования***:
# 1. Получим данные из исходных датасетов
# 2. Предобработаем данные: поищем пропуски, удалим дубликаты.
# 3. Проведем исследовательский анализ данных всех полученных датасетов
# 4. Объединим имеющиеся данные в одну таблицу для дальнейшей работы с ней
# 5. Поищем корреляцию между признаками чтобы не стоить модель по походим признакам
# 6. Постороим модель с использованием пайплана, найдем лучшую при переборе параметров
# 7. С помощью SHAP проанализируем важность признаков
# 8. Выделим один сегмент покупателей и посмотрим, как можно попробовать увеличить покупки в нем.
# 9. Сделаем общий вывод по работе, дадим рекомендации сервису

# %%
pip install phik -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install shap -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install scikit-learn==1.5.0 -q
# !pip install --upgrade shap matplotlib seaborn -q

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler, MinMaxScaler, RobustScaler, LabelEncoder
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, roc_auc_score, fbeta_score, f1_score
from sklearn.metrics import recall_score, precision_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
import phik
from phik.report import plot_correlation_matrix
from phik import phik_matrix
import shap
sns.set_theme(style="whitegrid")
RANDOM_STATE = 42

# %% [markdown]
# #### Загрузка данных

# %%
try:
    market_file = pd.read_csv('/datasets/market_file.csv', sep=",")
    print('Код выполняется на платформе')
except FileNotFoundError:
    market_file = pd.read_csv('datasets/market_file.csv', sep=",")
    print('Код выполняется локально')
# Out:
# Код выполняется локально

# %%
try:
    market_money = pd.read_csv('/datasets/market_money.csv', sep=",")
    print('Код выполняется на платформе')
except FileNotFoundError:
    market_money = pd.read_csv('datasets/market_money.csv', sep=",")
    print('Код выполняется локально')
# Out:
# Код выполняется локально

# %%
try:
    market_time = pd.read_csv('/datasets/market_time.csv', sep=",")
    print('Код выполняется на платформе')
except FileNotFoundError:
    market_time = pd.read_csv('datasets/market_time.csv', sep=",")
    print('Код выполняется локально')
# Out:
# Код выполняется локально

# %%
try:
    money = pd.read_csv('/datasets/money.csv', sep=";")
    print('Код выполняется на платформе')
except FileNotFoundError:
    money = pd.read_csv('datasets/money.csv', sep=";")
    print('Код выполняется локально')
# Out:
# Код выполняется локально

# %% [markdown]
# ##### Просмотр информации о датафреймах

# %%
print(market_file.info())
market_file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   Покупательская активность            1300 non-null   object
#  2   Тип сервиса                          1300 non-null   object
#  3   Разрешить сообщать                   1300 non-null   object
#  4   Маркет_актив_6_мес                   1300 non-null   float64
#  5   Маркет_актив_тек_мес                 1300 non-null   int64
#  6   Длительность                         1300 non-null   int64
#  7   Акционные_покупки                    1300 non-null   float64
#  8   Популярная_категория                 1300 non-null   object
#  9   Средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  Неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
print(market_money.info())
market_money
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   Период   3900 non-null   object
#  2   Выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB
# None
#           id               Период  Выручка
# 0     215348  препредыдущий_месяц      0.0
# 1     215348        текущий_месяц   3293.1
# 2     215348     предыдущий_месяц      0.0
# 3     215349  препредыдущий_месяц   4472.0
# 4     215349        текущий_месяц   4971.6
# ...      ...                  ...      ...
# 3895  216646  препредыдущий_месяц   4725.0
# 3896  216646     предыдущий_месяц   4923.0
# 3897  216647     предыдущий_месяц   4720.0
# 3898  216647  препредыдущий_месяц   5183.0
# 3899  216647        текущий_месяц   4448.3
#
# [3900 rows x 3 columns]

# %%
print(market_time.info())
market_time
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   Период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB
# None
#           id            Период  минут
# 0     215348     текущий_месяц     14
# 1     215348  предыдцщий_месяц     13
# 2     215349     текущий_месяц     10
# 3     215349  предыдцщий_месяц     12
# 4     215350     текущий_месяц     13
# ...      ...               ...    ...
# 2595  216645     текущий_месяц     18
# 2596  216646  предыдцщий_месяц     18
# 2597  216646     текущий_месяц      7
# 2598  216647     текущий_месяц     10
# 2599  216647  предыдцщий_месяц     15
#
# [2600 rows x 3 columns]

# %%
print(money.info())
money
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   Прибыль  1300 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 20.4+ KB
# None
#           id Прибыль
# 0     215348    0,98
# 1     215349    4,16
# 2     215350    3,13
# 3     215351    4,87
# 4     215352    4,21
# ...      ...     ...
# 1295  216643    4,44
# 1296  216644    6,11
# 1297  216645    3,29
# 1298  216646    4,03
# 1299  216647    3,28
#
# [1300 rows x 2 columns]

# %% [markdown]
# #### Предобработка данных

# %%
market_file.columns = market_file.columns.str.lower().str.replace(' ', '_')
market_file.loc[market_file['тип_сервиса'] == 'стандартт', 'тип_сервиса'] = 'стандарт'
market_file.columns
# Out:
# Index(['id', 'покупательская_активность', 'тип_сервиса', 'разрешить_сообщать',
#        'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',
#        'акционные_покупки', 'популярная_категория',
#        'средний_просмотр_категорий_за_визит',
#        'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса',
#        'страниц_за_визит'],
#       dtype='object')

# %%
market_file['маркет_актив_тек_мес'].unique()
# Out:
# array([5, 4, 3])

# %%
market_money.columns = market_money.columns.str.lower().str.replace(' ', '_')
market_money.columns
# Out:
# Index(['id', 'период', 'выручка'], dtype='object')

# %%
market_money['выручка'].unique()
# Out:
# array([   0. , 3293.1, 4472. , ..., 5224.6, 4720. , 4448.3])

# %%
market_time.columns = market_time.columns.str.lower().str.replace(' ', '_')
market_time.loc[market_time['период'] == 'предыдцщий_месяц', 'период'] = 'предыдущий_месяц'
market_time.columns
# Out:
# Index(['id', 'период', 'минут'], dtype='object')

# %%
market_time['период'].unique()
# Out:
# array(['текущий_месяц', 'предыдущий_месяц'], dtype=object)

# %%
money.columns = money.columns.str.lower().str.replace(' ', '_')
money['прибыль'] = money['прибыль'].str.replace(',', '.').astype('float64', errors='raise')
money.columns
# Out:
# Index(['id', 'прибыль'], dtype='object')

# %%
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %%
market_file[market_file.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, покупательская_активность, тип_сервиса, разрешить_сообщать, маркет_актив_6_мес, маркет_актив_тек_мес, длительность, акционные_покупки, популярная_категория, средний_просмотр_категорий_за_визит, неоплаченные_продукты_штук_квартал, ошибка_сервиса, страниц_за_визит]
# Index: []

# %%
market_money[market_money.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, период, выручка]
# Index: []

# %%
market_time[market_time.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, период, минут]
# Index: []

# %%
money[money.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, прибыль]
# Index: []

# %% [markdown]
# Данные предобработаны, дубликаты не найдены, пропусков нет.

# %% [markdown]
# #### Исследовательский анализ данных

# %% [markdown]
# ##### Анализ таблицы market_file

# %%
market_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   покупательская_активность            1300 non-null   object
#  2   тип_сервиса                          1300 non-null   object
#  3   разрешить_сообщать                   1300 non-null   object
#  4   маркет_актив_6_мес                   1300 non-null   float64
#  5   маркет_актив_тек_мес                 1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   популярная_категория                 1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %%
market_file.drop(columns='id').describe().T
# Out:
#                                       count        mean         std    min  \
# маркет_актив_6_мес                   1300.0    4.253769    1.014814    0.9
# маркет_актив_тек_мес                 1300.0    4.011538    0.696868    3.0
# длительность                         1300.0  601.898462  249.856289  110.0
# акционные_покупки                    1300.0    0.319808    0.249843    0.0
# средний_просмотр_категорий_за_визит  1300.0    3.270000    1.355350    1.0
# неоплаченные_продукты_штук_квартал   1300.0    2.840000    1.971451    0.0
# ошибка_сервиса                       1300.0    4.185385    1.955298    0.0
# страниц_за_визит                     1300.0    8.176923    3.978126    1.0
#
#                                         25%     50%    75%      max
# маркет_актив_6_мес                     3.70    4.20    4.9     6.60
# маркет_актив_тек_мес                   4.00    4.00    4.0     5.00
# длительность                         405.50  606.00  806.0  1079.00
# ...

# %%
numeric_col = market_file.select_dtypes('number').columns[1:].to_list()
numeric_col
# Out:
# ['маркет_актив_6_мес',
#  'маркет_актив_тек_мес',
#  'длительность',
#  'акционные_покупки',
#  'средний_просмотр_категорий_за_визит',
#  'неоплаченные_продукты_штук_квартал',
#  'ошибка_сервиса',
#  'страниц_за_визит']

# %%
numeric_col = ['длительность',
       'маркет_актив_6_мес',
       'акционные_покупки',
       'ошибка_сервиса',
       'страниц_за_визит']

# %%
category_col = market_file.select_dtypes('object').columns
category_col
# Out:
# Index(['покупательская_активность', 'тип_сервиса', 'разрешить_сообщать',
#        'популярная_категория'],
#       dtype='object')

# %%
category_col = ['покупательская_активность', 'тип_сервиса', 'разрешить_сообщать',
       'средний_просмотр_категорий_за_визит',
       'неоплаченные_продукты_штук_квартал',
       'маркет_актив_тек_мес',
       'популярная_категория']

# %%
fig, axes = plt.subplots(len(category_col), figsize=(7,30))
i = 0
plt.subplots_adjust(hspace=0.3)
for column in category_col:
    axes[i].set_title(f'Гистограмма для параметра \n {category_col[i]}')
    ax = sns.histplot(ax = axes[i], data=market_file, x=column, discrete=True)
    ax.set(xlabel=None)
    if column == 'популярная_категория':
        ax.tick_params(labelrotation=90)
    i += 1

# %%
fig, axes = plt.subplots(len(numeric_col), 2, figsize=(10,25))
i = 0
plt.subplots_adjust(hspace=0.3)
for column in numeric_col:
    axes[i,0].set_title(f'KDE для параметра \n {column}')
    axes[i,1].set_title(f'Boxplot для параметра \n {column}')
    sns.kdeplot(ax = axes[i,0], data=market_file, x=column).set(xlabel=None)
    sns.boxplot(ax = axes[i,1], data=market_file, x=column).set(xlabel=None)
    i += 1

# %% [markdown]
# ##### Анализ таблицы market_money

# %%
market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   период   3900 non-null   object
#  2   выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %%
market_money
# Out:
#           id               период  выручка
# 0     215348  препредыдущий_месяц      0.0
# 1     215348        текущий_месяц   3293.1
# 2     215348     предыдущий_месяц      0.0
# 3     215349  препредыдущий_месяц   4472.0
# 4     215349        текущий_месяц   4971.6
# ...      ...                  ...      ...
# 3895  216646  препредыдущий_месяц   4725.0
# 3896  216646     предыдущий_месяц   4923.0
# 3897  216647     предыдущий_месяц   4720.0
# 3898  216647  препредыдущий_месяц   5183.0
# 3899  216647        текущий_месяц   4448.3
#
# [3900 rows x 3 columns]

# %%
market_money['выручка'].describe()
# Out:
# count      3900.000000
# mean       5025.696051
# std        1777.704104
# min           0.000000
# 25%        4590.150000
# 50%        4957.500000
# 75%        5363.000000
# max      106862.200000
# Name: выручка, dtype: float64

# %%
market_money.groupby(by='период')['выручка'].sum()
# Out:
# период
# предыдущий_месяц       6417996.5
# препредыдущий_месяц    6272769.0
# текущий_месяц          6909449.1
# Name: выручка, dtype: float64

# %%
market_money.groupby(by='период')['выручка'].sum().plot.bar()
# Out:
# <Axes: xlabel='период'>

# %% [markdown]
# ##### Анализ таблицы market_time

# %%
market_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2600 non-null   int64
#  1   период  2600 non-null   object
#  2   минут   2600 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.1+ KB

# %%
market_time
# Out:
#           id            период  минут
# 0     215348     текущий_месяц     14
# 1     215348  предыдущий_месяц     13
# 2     215349     текущий_месяц     10
# 3     215349  предыдущий_месяц     12
# 4     215350     текущий_месяц     13
# ...      ...               ...    ...
# 2595  216645     текущий_месяц     18
# 2596  216646  предыдущий_месяц     18
# 2597  216646     текущий_месяц      7
# 2598  216647     текущий_месяц     10
# 2599  216647  предыдущий_месяц     15
#
# [2600 rows x 3 columns]

# %%
market_time['минут'].describe()
# Out:
# count    2600.000000
# mean       13.336154
# std         4.080198
# min         4.000000
# 25%        10.000000
# 50%        13.000000
# 75%        16.000000
# max        23.000000
# Name: минут, dtype: float64

# %%
market_time.groupby(by='период')['минут'].sum()
# Out:
# период
# предыдущий_месяц    17508
# текущий_месяц       17166
# Name: минут, dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,5))
plt.subplots_adjust(hspace=0.3)
axes[0].set_title(f'KDE для параметра \n время на сайте')
axes[1].set_title(f'Boxplot для параметра \n времмя на сайте')
sns.kdeplot(ax = axes[0], data=market_time, x='минут').set(xlabel=None)
sns.boxplot(ax = axes[1], data=market_time, x='минут').set(xlabel=None)
# Out:
# [Text(0.5, 0, '')]

# %% [markdown]
# ##### Анализ таблицы money

# %%
money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1300 non-null   int64
#  1   прибыль  1300 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 20.4 KB

# %%
money
# Out:
#           id  прибыль
# 0     215348     0.98
# 1     215349     4.16
# 2     215350     3.13
# 3     215351     4.87
# 4     215352     4.21
# ...      ...      ...
# 1295  216643     4.44
# 1296  216644     6.11
# 1297  216645     3.29
# 1298  216646     4.03
# 1299  216647     3.28
#
# [1300 rows x 2 columns]

# %%
money['прибыль'].describe()
# Out:
# count    1300.000000
# mean        3.996631
# std         1.013722
# min         0.860000
# 25%         3.300000
# 50%         4.045000
# 75%         4.670000
# max         7.430000
# Name: прибыль, dtype: float64

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,5))
plt.subplots_adjust(hspace=0.3)
axes[0].set_title(f'KDE для параметра \n прибыль')
axes[1].set_title(f'Boxplot для параметра \n прибыль')
sns.kdeplot(ax = axes[0], data=money, x='прибыль').set(xlabel=None)
sns.boxplot(ax = axes[1], data=money, x='прибыль').set(xlabel=None)
# Out:
# [Text(0.5, 0, '')]

# %% [markdown]
# ##### Выводы по анализу данных

# %% [markdown]
# По полученным данным можно сказать, что у большинства клиентов уровень активности не снижался, в основном используют стандартный сервис, большинство разрешило сообщать о предложениях, в среднем просматривают 3 категории и имеют 1-2 неоплаченные покупки. У пользователей в среднем 4 маркетинговых коммуникации. Самая популярная категория товары для детей, наименее популярная кухонная посуда.
#
# Средняя и медианная выручка с пользователя составляют примерно 5000 в месяц, при этом в общей выручке видно небольшое увеличения за текущий период относительно 2х предыдущих.
#
# Пользователи в среднем проводят 13 минут на сайте.
#
# Средняя прибыль от пользователя 4; с разбросом от 1 до 7, за исключением нескольких значений.

# %%
market_money.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3900 non-null   int64
#  1   период   3900 non-null   object
#  2   выручка  3900 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# Все пользователи потратили хоть что-то за последние 3 месяца, поэтому их всех и будем изучать

# %% [markdown]
# #### Объединение таблиц

# %%
all_data = market_file.copy(deep=True)
for money_period in market_money['период'].unique():
    column_name = 'выручка_' + money_period
    all_data = all_data.merge(market_money[market_money['период'] == money_period][['id', 'выручка']],\
                              on='id', how='left', suffixes=(None, column_name))
    all_data.rename(columns = {'выручка': column_name}, inplace=True)
    print(f'добавлена колонка {column_name}')
for time_period in market_time['период'].unique():
    column_name = 'минут_' + time_period
    all_data = all_data.merge(market_time[market_time['период'] == time_period][['id', 'минут']],\
                              on='id', how='left', suffixes=(None, column_name))
    all_data.rename(columns = {'минут': column_name}, inplace=True)
    print(f'добавлена колонка {column_name}')
all_data = all_data.set_index('id')
all_data = all_data[all_data['выручка_текущий_месяц'] < 10000]
# Out:
# добавлена колонка выручка_препредыдущий_месяц
# добавлена колонка выручка_текущий_месяц
# добавлена колонка выручка_предыдущий_месяц
# добавлена колонка минут_текущий_месяц
# добавлена колонка минут_предыдущий_месяц

# %%
all_data.describe().T
# Out:
#                                       count         mean         std     min  \
# маркет_актив_6_мес                   1299.0     4.255735    1.012725     0.9
# маркет_актив_тек_мес                 1299.0     4.011547    0.697136     3.0
# длительность                         1299.0   601.871440  249.950617   110.0
# акционные_покупки                    1299.0     0.319330    0.249345     0.0
# средний_просмотр_категорий_за_визит  1299.0     3.270208    1.355852     1.0
# неоплаченные_продукты_штук_квартал   1299.0     2.840647    1.972073     0.0
# ошибка_сервиса                       1299.0     4.185527    1.956044     0.0
# страниц_за_визит                     1299.0     8.177829    3.979524     1.0
# выручка_препредыдущий_месяц          1299.0  4825.033102  406.087624     0.0
# выручка_текущий_месяц                1299.0  5236.787452  835.474686  2758.7
# выручка_предыдущий_месяц             1299.0  4936.042725  739.205300     0.0
# ...

# %%
all_data = all_data

# %% [markdown]
# Объединили все данные в один датафрейм, так как нет информации о времени на сайте для препредыдущего месяца, оставили nan.

# %% [markdown]
# #### Корреляционный анализ

# %%
interval_cols = all_data.select_dtypes('number').columns.to_list()
interval_cols
# Out:
# ['маркет_актив_6_мес',
#  'маркет_актив_тек_мес',
#  'длительность',
#  'акционные_покупки',
#  'средний_просмотр_категорий_за_визит',
#  'неоплаченные_продукты_штук_квартал',
#  'ошибка_сервиса',
#  'страниц_за_визит',
#  'выручка_препредыдущий_месяц',
#  'выручка_текущий_месяц',
#  'выручка_предыдущий_месяц',
#  'минут_текущий_месяц',
#  'минут_предыдущий_месяц']

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(all_data[interval_cols].corr(method='pearson'), annot=True, fmt='.2f', ax=ax)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(all_data[interval_cols].corr(method='kendall'), annot=True, fmt='.2f', ax=ax)
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(all_data[interval_cols].corr(method='spearman'), annot=True, fmt='.2f', ax=ax)
# Out:
# <Axes: >

# %%
phik_overview = all_data.phik_matrix(interval_cols=interval_cols)
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=1.5,
    figsize=(20, 15)
)

# %% [markdown]
# Судя по матрицам корреляции, сильной зависимости как между количественными, так и качественными признаками нет, поэтому ничего изменять для дальнейшего анализа не будем. Хотя стоить отметить довольно сильную сильную зависимость количества минут и страниц за визит от покупательской активности, скорее всего это зависимые друг от друга признаки.

# %% [markdown]
# #### Использование пайплайнов

# %%
all_data.columns
# Out:
# Index(['покупательская_активность', 'тип_сервиса', 'разрешить_сообщать',
#        'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',
#        'акционные_покупки', 'популярная_категория',
#        'средний_просмотр_категорий_за_визит',
#        'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса',
#        'страниц_за_визит', 'выручка_препредыдущий_месяц',
#        'выручка_текущий_месяц', 'выручка_предыдущий_месяц',
#        'минут_текущий_месяц', 'минут_предыдущий_месяц'],
#       dtype='object')

# %% [markdown]
# Для дальнейших расчетов обозначим снижение активности как 1, а прежний уровень как 0.

# %%
label_encoder = LabelEncoder()
print(all_data['покупательская_активность'].head(2))
all_data['покупательская_активность'] = label_encoder.fit_transform(all_data['покупательская_активность'])
print(all_data['покупательская_активность'].head(2))
# Out:
# id
# 215348    Снизилась
# 215349    Снизилась
# Name: покупательская_активность, dtype: object
# id
# 215348    1
# 215349    1
# Name: покупательская_активность, dtype: int64

# %%
all_data.describe().T
# Out:
#                                       count         mean         std     min  \
# покупательская_активность            1299.0     0.382602    0.486210     0.0
# маркет_актив_6_мес                   1299.0     4.255735    1.012725     0.9
# маркет_актив_тек_мес                 1299.0     4.011547    0.697136     3.0
# длительность                         1299.0   601.871440  249.950617   110.0
# акционные_покупки                    1299.0     0.319330    0.249345     0.0
# средний_просмотр_категорий_за_визит  1299.0     3.270208    1.355852     1.0
# неоплаченные_продукты_штук_квартал   1299.0     2.840647    1.972073     0.0
# ошибка_сервиса                       1299.0     4.185527    1.956044     0.0
# страниц_за_визит                     1299.0     8.177829    3.979524     1.0
# выручка_препредыдущий_месяц          1299.0  4825.033102  406.087624     0.0
# выручка_текущий_месяц                1299.0  5236.787452  835.474686  2758.7
# ...

# %%
X = all_data.drop(columns = 'покупательская_активность')
y = all_data['покупательская_активность']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=RANDOM_STATE, stratify = all_data['покупательская_активность'])

# %%
ohe_columns = [
    'разрешить_сообщать',
    'популярная_категория',
]
ord_columns = ['тип_сервиса'
]
num_columns = [
       'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',
       'акционные_покупки', 'средний_просмотр_категорий_за_визит',
       'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса', 'выручка_препредыдущий_месяц',
       'выручка_текущий_месяц', 'выручка_предыдущий_месяц',
       'минут_текущий_месяц', 'минут_предыдущий_месяц',
       'страниц_за_визит'
]

# %%
ohe_pipe = Pipeline(
    [
        (
            'simpleImputer_ohe', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ohe', 
            OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False)
        )
    ]
)

# %%
for column in ord_columns:
    print(column, sorted(all_data[column].unique().tolist()))
# Out:
# тип_сервиса ['премиум', 'стандарт']

# %%
ord_pipe = Pipeline(
    [
        (
            'simpleImputer_before_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ord',
            OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=np.nan,
            categories=[['стандарт', 'премиум']]
            )
        ),
        (
            'simpleImputer_after_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)

# %%
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns),
        ('ord', ord_pipe, ord_columns),
        ('num', StandardScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %%
final_pipe = Pipeline(
    [
        ('preprocessor', data_preprocessor),
        ('models', KNeighborsClassifier())
    ]
)

# %%
param_grid = [
    # словарь для модели KNeighborsClassifier() 
    {
        # название модели
        'models': [KNeighborsClassifier()],
        # указываем гиперпараметр модели n_neighbors
        'models__n_neighbors': range(1, 20),
        # указываем список методов масштабирования
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]   
    },
    # словарь для модели DecisionTreeClassifier()
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE, class_weight='balanced')],
        'models__max_depth': range(2, 20),
        'models__min_samples_leaf': range(1, 5),
        'models__min_samples_split': range(2, 6),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    # словарь для модели SVC()
    {
        'models': [SVC(random_state=RANDOM_STATE, class_weight='balanced')],
        'models__C': [0.01, 0.1, 0.4, 0.7, 1.0, 10, 100],
        'models__kernel': ['linear', 'rbf', 'sigmoid'],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  

    },
    # словарь для модели poly SVC()
    {
        'models': [SVC(random_state=RANDOM_STATE, class_weight='balanced', kernel='poly')],
        'models__C': [0.01, 0.1, 0.4, 0.7, 1.0, 10, 30, 100],
        'models__degree': range(1,6),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  

    },
    # словарь для модели LogisticRegression()
    {
        'models': [LogisticRegression(random_state=RANDOM_STATE, class_weight='balanced')],
        'models__C': [0.1, 0.4, 0.7, 1.0],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    },
    # словарь для второй модели LogisticRegression()
    {
        'models': [LogisticRegression(random_state=RANDOM_STATE, class_weight='balanced', solver='saga')],
        'models__penalty': ['l1', 'elasticnet'],
        'models__C': [0.1, 0.4, 0.7, 1.0],
        'models__l1_ratio': [0.1, 0.4, 0.7, 1.0],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']  
    }
]

# %%
def refit_strategy(cv_results):
    roc_auc_threshold = 0.8
    f1_treshold = 0.7
    cv_results_ = pd.DataFrame(cv_results)
    high_roc_auc_cv_results = cv_results_[cv_results_["mean_test_roc_auc"] > roc_auc_threshold]
    medium_f1_cv_results = high_roc_auc_cv_results[high_roc_auc_cv_results["mean_test_f1"] > f1_treshold]
    best_roc_auc_cv_results_index = medium_f1_cv_results['mean_test_recall'].idxmax()
    return best_roc_auc_cv_results_index

# %%
grid_search = GridSearchCV(
    final_pipe, 
    param_grid=param_grid,
    cv=5,
    scoring=['roc_auc', 'recall', 'f1'],
    n_jobs=-1,
    error_score='raise',
    refit=refit_strategy
)
grid_search.fit(X_train, y_train)
print(grid_search.best_estimator_)
# Out:
# C:\Users\paulv\AppData\Roaming\Python\Python39\site-packages\numpy\ma\core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
# ...

# %%
result = pd.DataFrame(grid_search.cv_results_)
result.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_models', 'param_models__n_neighbors', 'param_preprocessor__num',
#        'param_models__max_depth', 'param_models__min_samples_leaf',
#        'param_models__min_samples_split', 'param_models__C',
#        'param_models__kernel', 'param_models__degree',
#        'param_models__l1_ratio', 'param_models__penalty', 'params',
#        'split0_test_roc_auc', 'split1_test_roc_auc', 'split2_test_roc_auc',
#        'split3_test_roc_auc', 'split4_test_roc_auc', 'mean_test_roc_auc',
#        'std_test_roc_auc', 'rank_test_roc_auc', 'split0_test_recall',
#        'split1_test_recall', 'split2_test_recall', 'split3_test_recall',
#        'split4_test_recall', 'mean_test_recall', 'std_test_recall',
#        'rank_test_recall', 'split0_test_f1', 'split1_test_f1',
#        'split2_test_f1', 'split3_test_f1', 'split4_test_f1', 'mean_test_f1',
#        'std_test_f1', 'rank_test_f1'],
#       dtype='object')

# %%
output_result = result[['mean_test_recall',
                        'mean_test_roc_auc',
                        'mean_test_f1','params']].sort_values('mean_test_recall', ascending=False)
output_result[output_result['mean_test_recall'] > 0.8].head(10)
# Out:
#       mean_test_recall  mean_test_roc_auc  mean_test_f1  \
# 994           0.841730           0.743968      0.642845
# 949           0.828468           0.900412      0.803844
# 958           0.815063           0.898880      0.797728
# 940           0.812252           0.900783      0.795045
# 1145          0.807027           0.904195      0.813865
# 1157          0.807027           0.904195      0.813865
# 1151          0.807027           0.904195      0.813865
# 1163          0.807027           0.904195      0.813865
# 1166          0.807027           0.904195      0.813865
# 1003          0.804432           0.750796      0.647242
#
#                                                  params
# 994   {'models': SVC(class_weight='balanced', kernel...
# 949   {'models': SVC(class_weight='balanced', random...
# 958   {'models': SVC(class_weight='balanced', random...
# 940   {'models': SVC(class_weight='balanced', random...
# 1145  {'models': LogisticRegression(class_weight='ba...
# ...

# %%
output_result.loc[940, 'params']
# Out:
# {'models': SVC(class_weight='balanced', random_state=42),
#  'models__C': 1.0,
#  'models__kernel': 'linear',
#  'preprocessor__num': 'passthrough'}

# %%
grid_search.best_params_
# Out:
# {'models': SVC(class_weight='balanced', random_state=42),
#  'models__C': 10,
#  'models__kernel': 'linear',
#  'preprocessor__num': 'passthrough'}

# %%
y_test_pred = grid_search.predict(X_test)
print(f"Precision score: {precision_score(y_test, y_test_pred)}")
print(f"Recall score: {recall_score(y_test, y_test_pred)}")
print(f"roc-auc score: {roc_auc_score(y_test, y_test_pred)}")
# Out:
# Precision score: 0.7923076923076923
# Recall score: 0.8306451612903226
# roc-auc score: 0.8481584015406837

# %%
cm = confusion_matrix(y_test, y_test_pred)
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >

# %%
print(y_test[y_test == 1].count())
print(len(y_test_pred[y_test_pred == 1]))
# Out:
# 124
# 130

# %% [markdown]
# Так как нам важнее предоставить скидку или акционное предложение тем, кто снизит покупательскую активность, использовали метрику recall. В результате лучшей моделью стала SVC(C=1, class_weight='balanced', kernel='linear'), метрика показала результат 0.84 при кросс-валидации и 0.83 на тестовых данных, что не так уж и плохо. Для более подробной оценки результата следует учесть экономические потери от снижения активности и от лишних акционных предложений. При этом метрика roc-auc также показывает высокий результат в 0.83 на тестовых данных. Остановим свой выбор на данной модели.

# %% [markdown]
# #### Анализ важности признаков

# %%
model = grid_search.best_estimator_.named_steps['models']
X_train_trans = grid_search.best_estimator_.named_steps['preprocessor'].fit_transform(X_train)
X_test_trans = grid_search.best_estimator_.named_steps['preprocessor'].transform(X_test)
feature_names=grid_search.best_estimator_.named_steps['preprocessor'].get_feature_names_out()
explainer = shap.Explainer(model.predict, X_train_trans, feature_names=feature_names)
shap_values = explainer(X_test_trans)
# Out:
# PermutationExplainer explainer: 326it [00:43,  6.14it/s]

# %%
shap.plots.beeswarm(shap_values, max_display=15)

# %%
mistakes_df = pd.DataFrame({'y_test': y_test, 'y_test_pred': y_test_pred}).reset_index()
mistakes_df = mistakes_df[(mistakes_df['y_test']==1)&(mistakes_df['y_test_pred']==0)]
index_mistakes = mistakes_df.index.tolist()
index_mistakes
# Out:
# [8,
#  12,
#  55,
#  67,
#  83,
#  92,
#  118,
#  142,
#  144,
#  152,
#  154,
#  167,
#  199,
#  200,
#  201,
#  210,
#  231,
#  281,
#  284,
#  288,
#  317]

# %%
for i in [8, 154, 281, 317]:
    shap.plots.waterfall(shap_values[i])

# %% [markdown]
# По анализу полученных результатов по методу SHAP можно сказать, что средний просмотр страниц за визит очень сильно влияет на вероятность снижения покупательской активности. Не менее важными остаются такие признаки, как количество минут на сайте за текущий или предыдущий месяц, а также количество просмотренных категорий. На акционных покупках можно наблюдать снижение активности при больших значениях этого параметра. Таким образом, люди, которые долго сидят на сайте и смотрят разные категории и страницы, скорее всего что-то ищут, но когда они уже что-то покупали по акции, не могут купить что-либо еще. Наличие неоплаченных товаров в корзине в большом количестве также снижает вероятность покупки. Поэтому стоит делать так, чтобы товаров в корзине была как можно меньше, это связано с тем, что люди хотят что-то купить, но у нихможет не хватать на это денег. По категорием при большом количестве покупок в категории электроника активность увеличивается. В косметике же наоборот.

# %% [markdown]
# #### Сегментация покупателей

# %% [markdown]
# Для исследования возьмем группу клиентов с высокой вероятностью снижения покупательской активности и наиболее высокой прибыльностью.

# %%
all_data['выручка_3_месяца'] = (all_data['выручка_препредыдущий_месяц'] +
                                all_data['выручка_текущий_месяц'] +
                                all_data['выручка_предыдущий_месяц'])
all_data['выручка_3_месяца'].describe()
# Out:
# count     1299.000000
# mean     14997.863279
# std       1656.706215
# min       3293.100000
# 25%      13942.300000
# 50%      15071.100000
# 75%      16085.550000
# max      19766.500000
# Name: выручка_3_месяца, dtype: float64

# %%
all_data_rich = all_data[all_data['выручка_3_месяца'] > all_data['выручка_3_месяца'].quantile(q=0.8)]
all_data_rich['покупательская_активность'] = all_data_rich['покупательская_активность'].apply(lambda x: 'снизилась' if x == 1 else 'Прежний уровень')
all_data_rich
# Out:
# C:\Users\paulv\AppData\Local\Temp\ipykernel_30532\900738316.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data_rich['покупательская_активность'] = all_data_rich['покупательская_активность'].apply(lambda x: 'снизилась' if x == 1 else 'Прежний уровень')
#        покупательская_активность тип_сервиса разрешить_сообщать  \
# id
# 215351                 снизилась    стандарт                 да
# 215360                 снизилась     премиум                 да
# 215363                 снизилась    стандарт                нет
# 215371                 снизилась    стандарт                 да
# 215376                 снизилась    стандарт                 да
# ...                          ...         ...                ...
# ...

# %%
all_data_rich.describe().T
# Out:
#                                      count          mean         std  \
# маркет_актив_6_мес                   260.0      4.271923    1.091464
# маркет_актив_тек_мес                 260.0      4.000000    0.680676
# длительность                         260.0    621.696154  242.803756
# акционные_покупки                    260.0      0.328846    0.256782
# средний_просмотр_категорий_за_визит  260.0      3.100000    1.266436
# неоплаченные_продукты_штук_квартал   260.0      3.026923    1.985285
# ошибка_сервиса                       260.0      4.353846    1.896396
# страниц_за_визит                     260.0      7.880769    3.886072
# выручка_препредыдущий_месяц          260.0   4989.069231  328.171798
# выручка_текущий_месяц                260.0   6370.415385  524.314637
# выручка_предыдущий_месяц             260.0   5844.065385  292.403562
# минут_текущий_месяц                  260.0     12.488462    4.346465
# минут_предыдущий_месяц               260.0     12.926923    3.722835
# ...

# %%
numeric_col = all_data_rich.select_dtypes('number').columns.to_list()
numeric_col
# Out:
# ['маркет_актив_6_мес',
#  'маркет_актив_тек_мес',
#  'длительность',
#  'акционные_покупки',
#  'средний_просмотр_категорий_за_визит',
#  'неоплаченные_продукты_штук_квартал',
#  'ошибка_сервиса',
#  'страниц_за_визит',
#  'выручка_препредыдущий_месяц',
#  'выручка_текущий_месяц',
#  'выручка_предыдущий_месяц',
#  'минут_текущий_месяц',
#  'минут_предыдущий_месяц',
#  'выручка_3_месяца']

# %%
category_col = all_data_rich.select_dtypes('object').columns
category_col
# Out:
# Index(['покупательская_активность', 'тип_сервиса', 'разрешить_сообщать',
#        'популярная_категория'],
#       dtype='object')

# %%
numeric_col = ['маркет_актив_6_мес',
               'маркет_актив_тек_мес',
               'длительность',
               'акционные_покупки',
               'ошибка_сервиса',
               'страниц_за_визит',
               'выручка_препредыдущий_месяц',
               'выручка_текущий_месяц',
               'выручка_предыдущий_месяц',
               'минут_текущий_месяц',
               'минут_предыдущий_месяц',
               'выручка_3_месяца']
category_col = ['покупательская_активность',
                'тип_сервиса',
                'разрешить_сообщать',
                'средний_просмотр_категорий_за_визит',
                'неоплаченные_продукты_штук_квартал',
                'популярная_категория']

# %%
fig, axes = plt.subplots(len(category_col), figsize=(7,30))
i = 0
plt.subplots_adjust(hspace=0.3)
for column in category_col:
    axes[i].set_title(f'Гистограмма для параметра \n {category_col[i]}')
    ax = sns.histplot(ax = axes[i], data=all_data_rich, x=column, discrete=True)
    ax.set(xlabel=None)
    if column == 'популярная_категория':
        ax.tick_params(labelrotation=90)
    i += 1

# %%
fig, axes = plt.subplots(len(numeric_col), 2, figsize=(10,35))
i = 0
plt.subplots_adjust(hspace=0.4)
for column in numeric_col:
    axes[i,0].set_title(f'KDE для параметра \n {column}')
    axes[i,1].set_title(f'Boxplot для параметра \n {column}')
    sns.kdeplot(ax = axes[i,0], data=all_data_rich, x=column).set(xlabel=None)
    sns.boxplot(ax = axes[i,1], data=all_data_rich, x=column).set(xlabel=None)
    i += 1

# %%
print(all_data_rich.columns)
print(all_data_rich['популярная_категория'].unique())
all_data_rich[all_data_rich['покупательская_активность'] == 'снизилась'].describe().T
# Out:
# Index(['покупательская_активность', 'тип_сервиса', 'разрешить_сообщать',
#        'маркет_актив_6_мес', 'маркет_актив_тек_мес', 'длительность',
#        'акционные_покупки', 'популярная_категория',
#        'средний_просмотр_категорий_за_визит',
#        'неоплаченные_продукты_штук_квартал', 'ошибка_сервиса',
#        'страниц_за_визит', 'выручка_препредыдущий_месяц',
#        'выручка_текущий_месяц', 'выручка_предыдущий_месяц',
#        'минут_текущий_месяц', 'минут_предыдущий_месяц', 'выручка_3_месяца'],
#       dtype='object')
# ['Товары для детей' 'Кухонная посуда' 'Домашний текстиль'
#  'Техника для красоты и здоровья' 'Косметика и аксесуары'
#  'Мелкая бытовая техника и электроника']
#                                      count          mean         std  \
# маркет_актив_6_мес                   110.0      3.710909    1.100487
# маркет_актив_тек_мес                 110.0      4.000000    0.690698
# длительность                         110.0    649.209091  209.453684
# ...

# %%
X_rich = all_data_rich.drop(columns='покупательская_активность')
X_rich_trans = grid_search.best_estimator_.named_steps['preprocessor'].transform(X_rich)
shap_values = explainer(X_rich_trans)
# Out:
# PermutationExplainer explainer: 261it [00:32,  5.56it/s]

# %%
shap.plots.beeswarm(shap_values, max_display=15)

# %% [markdown]
# Для выбранного сегмента покупателей можем видеть, что в среднем смотрят 3 категории за визит, посещают 6 страниц за визит и сидят на сайте около 10 минут в предыдущем и в текущем месяце. При этом можно увидеть, что увеличение количества акционных покупок снижает активность, а низкое количество почти не влияет на активность. Поэтому делать какие-либо скидки не целесообразно. Лучше попробовать переманить пользователей из категорий текстиль и косметика в другие.
#
# Данный сегмент был выбран, так как именно эти люди тратят больше всего денег, соответственно они и имеют больше возможностей что-либо купить. Мелкие и повседневные покупки все делают всегда, поэтому повлиять на их активность сложнее.

# %% [markdown]
# #### Общие выводы

# %% [markdown]
# Нами были получены исходные данные от Интернет-магазин «В один клик». Эти данные были предобработаны, проведен их исследовательский анализ. Из этого анализа следует, что:
# - у большиства пользователей активность на прежнем уровне, они используют стандартный сервис, им можно присылать уведомления
# - Просматривается около 3 категорий за визит и есть 1-2 неоплаченных товара в корзине
# - Самая популярная категория товары для детей
# - смотрят 5 страниц за визит на сайт и проводят на сайте 13 минут
#
# Далее были объединены таблицы и проведенным корреляционный анализ данных, в результате не получили высокую корреляцию ни одного параметра с другим.
#
# Затем был создан пайплайн для трансформации данных и параметры моделей. С помощью greadsearchCV была найдена лучшая модель для предсказания целевого признака (покупательской активности). лучшей моделью стала SVC(C=1, class_weight='balanced', kernel='linear'), метрика показала результат 0.84 при кросс-валидации и 0.83 на тестовых данных, что не так уж и плохо. Для более подробной оценки результата следует учесть экономические потери от снижения активности и от лишних акционных предложений. При этом метрика roc-auc также показывает высокий результат в 0.83 на тестовых данных. Для более подробной оценки результата следует учесть экономические потери от снижения активности и от лишних акционных предложений. При этом метрика roc-auc также показывает высокий результат в 0.78 на тестовых данных.
#
#
# Следом проведен анализ важности признаков с помощью shap. Он показал, что средний просмотр категорий за визит очень сильно влияет на вероятность снижения покупательской активности. Не менее важными остаются такие признаки, как количество минут на сайте за текущий или предыдущий месяц. На акционных покупках можно наблюдать снижение активности при больших значениях этого параметра. Таким образом, люди, которые долго сидят на сайте и смотрят разные категории, ищут конкретные товары и в итоге покупают их. Наличие неоплаченных товар в корзине в большом количестве также снижает вероятность покупки.
#
# Вслед за этим был выделен сегмент покупателей с наибольшими затратами на покупки. В отличии от большинства, самой популярной категорией у него стала домашний текстиль и косметика, а не товары для детей. При этом в текущем месяце они проводили на сайте 10 минут, чуть меньше, чем большинство, но также в среднем просматривали 3 категори товаров. Также у чуть большего числа людей снизилась покупательская активность. При этом можно увидеть, что увеличение количества акционных покупок снижает активность, а низкое количество почти не влияет на активность. Поэтому делать какие-либо скидки не целесообразно. Лучше попробовать переманить пользователей из категорий текстиль и косметика в другие.
