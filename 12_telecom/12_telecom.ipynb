# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Введение" data-toc-modified-id="Введение-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Введение</a></span></li><li><span><a href="#Импорты-библиотек" data-toc-modified-id="Импорты-библиотек-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Импорты библиотек</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Объединение-датафреймов" data-toc-modified-id="Объединение-датафреймов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Объединение датафреймов</a></span></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Функции-для-графиков" data-toc-modified-id="Функции-для-графиков-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Функции для графиков</a></span></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Анализ данных</a></span></li><li><span><a href="#Добавление-новых-признаков" data-toc-modified-id="Добавление-новых-признаков-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Добавление новых признаков</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#RandomForestClassifier" data-toc-modified-id="RandomForestClassifier-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>RandomForestClassifier</a></span></li><li><span><a href="#SVC" data-toc-modified-id="SVC-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>SVC</a></span></li><li><span><a href="#CatBoostClassifier" data-toc-modified-id="CatBoostClassifier-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>CatBoostClassifier</a></span></li><li><span><a href="#LGBMClassifier" data-toc-modified-id="LGBMClassifier-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>LGBMClassifier</a></span></li></ul></li><li><span><a href="#Выбор-лучшей-модели" data-toc-modified-id="Выбор-лучшей-модели-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Выбор лучшей модели</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# Автор: Вересов Павел https://github.com/veresovpavel

# %% [markdown]
# ### Введение

# %% [markdown]
# <center><b>Телекоммуникации</b></center>
#
# Оператор связи «ТелеДом» хочет бороться с оттоком клиентов. Для этого его сотрудники начнут предлагать промокоды и специальные условия всем, кто планирует отказаться от услуг связи. Чтобы заранее находить таких пользователей, «ТелеДому» нужна модель, которая будет предсказывать, разорвёт ли абонент договор. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и услугах. Ваша задача — обучить на этих данных модель для прогноза оттока клиентов.
#
# Описание услуг
#
# Оператор предоставляет два основных типа услуг:
#
# Стационарную телефонную связь. Телефон можно подключить к нескольким линиям одновременно.
# Интернет. Подключение может быть двух типов: через телефонную линию (DSL, от англ. digital subscriber line — «цифровая абонентская линия») или оптоволоконный кабель (Fiber optic).
# Также доступны такие услуги:
#
# Интернет-безопасность: антивирус (DeviceProtection) и блокировка небезопасных сайтов (OnlineSecurity);
# Выделенная линия технической поддержки (TechSupport);
# Облачное хранилище файлов для резервного копирования данных (OnlineBackup);
# Стриминговое телевидение (StreamingTV) и каталог фильмов (StreamingMovies).
# Клиенты могут платить за услуги каждый месяц или заключить договор на 1–2 года. Возможно оплатить счёт разными способами, а также получить электронный чек.
# Описание данных
#
# Данные состоят из нескольких файлов, полученных из разных источников:
# - contract_new.csv — информация о договоре;
# - personal_new.csv — персональные данные клиента;
# - internet_new.csv — информация об интернет-услугах;
# - phone_new.csv — информация об услугах телефонии.
#
# Цель работы:
# - Изучить информацию о пользователях
# - Построить модель, на ее основе дать рекомендации по удержанию пользователей
#
# План работы:
#
# - Загрузим информацию в датафреймы и посмотрим информацию в них
# - Проанализируем данные, построим графики для всех пользователей, а также раздельные по ключевому признаку
# - Рассмотрим существующие признаки, создадим новые, если необходимо
# - Построим модели, определим лучшую
# - Проанализируем виляние признаков
# - Дадим рекомендации по удержанию клиентов

# %% [markdown]
# ### Импорты библиотек

# %%
# !pip install -q scikit-learn==1.5.0
# !pip install --upgrade matplotlib seaborn -q
# !pip install lightgbm -q
# !pip install catboost -q
# !pip install phik -q
# !pip install -q shap

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime
from IPython.display import Markdown, display
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier
from sklearn.svm import SVC
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler, PolynomialFeatures
from sklearn.metrics import roc_auc_score, confusion_matrix, ConfusionMatrixDisplay, roc_curve, RocCurveDisplay
import time
import phik
from phik.report import plot_correlation_matrix
from phik import phik_matrix
import shap
sns.set_theme(style="whitegrid")
RANDOM_STATE = 140725
start_time = time.perf_counter()

# %% [markdown]
# ### Загрузка данных

# %%
try:
    contract_new = pd.read_csv('/datasets/contract_new.csv', sep=",")
    personal_new = pd.read_csv('/datasets/personal_new.csv', sep=",")
    internet_new = pd.read_csv('/datasets/internet_new.csv', sep=",")
    phone_new = pd.read_csv('/datasets/phone_new.csv', sep=",")
    print('Код выполняется на платформе')
except FileNotFoundError:
    contract_new = pd.read_csv('datasets/contract_new.csv', sep=",")
    personal_new = pd.read_csv('datasets/personal_new.csv', sep=",")
    internet_new = pd.read_csv('datasets/internet_new.csv', sep=",")
    phone_new = pd.read_csv('datasets/phone_new.csv', sep=",")
    print('Код выполняется локально')
# Out:
# Код выполняется локально

# %%
dataframes = [contract_new, personal_new, internet_new, phone_new]

# %%
for df in dataframes:
    display(df.shape)
    display(df.head(3))
# Out:
# (7043, 8)
#    customerID   BeginDate EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG  2020-01-01      No  Month-to-month              Yes
# 1  5575-GNVDE  2017-04-01      No        One year               No
# 2  3668-QPYBK  2019-10-01      No  Month-to-month              Yes
#
#       PaymentMethod  MonthlyCharges TotalCharges
# 0  Electronic check           29.85        31.04
# 1      Mailed check           56.95      2071.84
# 2      Mailed check           53.85       226.17
# (7043, 5)
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# (5517, 8)
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# ...

# %%
for df in dataframes:
    display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
# ...

# %% [markdown]
# Во всех датафреймах нет пропущенных значений, но они отличаются по количеству строк. Далее объеденим все вместе и рассмотрим недостающие значения уже по все данным сразу.

# %% [markdown]
# ### Объединение датафреймов

# %%
for df in dataframes:
    df.set_index('customerID', inplace=True)

# %%
all_data = pd.concat(dataframes, axis='columns')
all_data.head(3)
# Out:
#              BeginDate EndDate            Type PaperlessBilling  \
# customerID
# 7590-VHVEG  2020-01-01      No  Month-to-month              Yes
# 5575-GNVDE  2017-04-01      No        One year               No
# 3668-QPYBK  2019-10-01      No  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges TotalCharges  gender  \
# customerID
# 7590-VHVEG  Electronic check           29.85        31.04  Female
# 5575-GNVDE      Mailed check           56.95      2071.84    Male
# 3668-QPYBK      Mailed check           53.85       226.17    Male
#
#             SeniorCitizen Partner Dependents InternetService OnlineSecurity  \
# customerID
# 7590-VHVEG              0     Yes         No             DSL             No
# 5575-GNVDE              0      No         No             DSL            Yes
# 3668-QPYBK              0      No         No             DSL            Yes
#
#            OnlineBackup DeviceProtection TechSupport StreamingTV  \
# customerID
# ...

# %%
all_data.shape
# Out:
# (7043, 19)

# %%
all_data[all_data.isna().any(axis=1)].shape
# Out:
# (2208, 19)

# %%
all_data[all_data.duplicated()].shape
# Out:
# (4, 19)

# %%
all_data[all_data.duplicated(keep=False)]
# Out:
#              BeginDate EndDate            Type PaperlessBilling  \
# customerID
# 4376-KFVRS  2014-02-01      No        Two year              Yes
# 2866-IKBTM  2020-01-01      No  Month-to-month               No
# 4312-KFRXN  2014-02-01      No        Two year               No
# 8605-ITULD  2020-01-01      No  Month-to-month               No
# 0673-IGUQO  2020-01-01      No  Month-to-month               No
# 2668-TZSPS  2020-01-01      No  Month-to-month               No
# 3892-NXAZG  2014-02-01      No        Two year              Yes
# 8774-GSBUN  2014-02-01      No        Two year               No
#
#                       PaymentMethod  MonthlyCharges TotalCharges  gender  \
# customerID
# 4376-KFVRS  Credit card (automatic)          114.05       8211.6    Male
# 2866-IKBTM             Mailed check           19.55        19.55  Female
# 4312-KFRXN             Mailed check           25.40       1828.8    Male
# ...

# %% [markdown]
# Дубликаты есть, но с разными ID, так что это, возможно, просто одинаковые люди, так как их немного. Эту информацию можно уточнить у поставщика данных.

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BeginDate         7043 non-null   object
#  1   EndDate           7043 non-null   object
#  2   Type              7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   object
#  7   gender            7043 non-null   object
#  8   SeniorCitizen     7043 non-null   int64
#  9   Partner           7043 non-null   object
#  10  Dependents        7043 non-null   object
#  11  InternetService   5517 non-null   object
#  12  OnlineSecurity    5517 non-null   object
#  13  OnlineBackup      5517 non-null   object
#  14  DeviceProtection  5517 non-null   object
#  15  TechSupport       5517 non-null   object
# ...

# %%
all_data[['BeginDate']] = all_data[['BeginDate']].apply(pd.to_datetime)

# %% [markdown]
# EndDate рассмотрим позже, это целевой признак и там есть особенности переделки в нужный формат

# %% [markdown]
# Так как TotalCharges почему-то объект, попробуем преобразовать в число, но также посмотрим на ошибки

# %%
all_data['TotalCharges'] = pd.to_numeric(all_data['TotalCharges'], errors='coerce')
error_indices = all_data[all_data['TotalCharges'].isna()].index.tolist()

if error_indices:
    print(f"Error found at indices: {error_indices}")
else:
    print("No errors found.")
# Out:
# Error found at indices: ['4472-LVYGI', '3115-CZMZD', '5709-LVOEQ', '4367-NUYAO', '1371-DWPAZ', '7644-OMVMY', '3213-VVOLG', '2520-SGTTA', '2923-ARZLG', '4075-WKNIU', '2775-SEFEE']

# %%
all_data.loc[error_indices]
# Out:
#             BeginDate EndDate      Type PaperlessBilling  \
# customerID
# 4472-LVYGI 2020-02-01      No  Two year              Yes
# 3115-CZMZD 2020-02-01      No  Two year               No
# 5709-LVOEQ 2020-02-01      No  Two year               No
# 4367-NUYAO 2020-02-01      No  Two year               No
# 1371-DWPAZ 2020-02-01      No  Two year               No
# 7644-OMVMY 2020-02-01      No  Two year               No
# 3213-VVOLG 2020-02-01      No  Two year               No
# 2520-SGTTA 2020-02-01      No  Two year               No
# 2923-ARZLG 2020-02-01      No  One year              Yes
# 4075-WKNIU 2020-02-01      No  Two year               No
# 2775-SEFEE 2020-02-01      No  Two year              Yes
#
#                         PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# customerID
# 4472-LVYGI  Bank transfer (automatic)           52.55           NaN  Female
# 3115-CZMZD               Mailed check           20.25           NaN    Male
# ...

# %%
all_data.loc[error_indices, 'TotalCharges'] = 0

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BeginDate         7043 non-null   datetime64[ns]
#  1   EndDate           7043 non-null   object
#  2   Type              7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   float64
#  7   gender            7043 non-null   object
#  8   SeniorCitizen     7043 non-null   int64
#  9   Partner           7043 non-null   object
#  10  Dependents        7043 non-null   object
#  11  InternetService   5517 non-null   object
#  12  OnlineSecurity    5517 non-null   object
#  13  OnlineBackup      5517 non-null   object
#  14  DeviceProtection  5517 non-null   object
#  15  TechSupport       5517 non-null   object
# ...

# %% [markdown]
# Пропуски в общих платежах для тех, кто только что зарегистрировался

# %% [markdown]
# ### Анализ данных

# %% [markdown]
# #### Функции для графиков

# %%
def figures_for_num(data, numeric_col, hue=None):
    if len(numeric_col) != 1:
        fig, axes = plt.subplots(len(numeric_col), 2, figsize=(10,len(numeric_col)*5))
        i = 0
        plt.subplots_adjust(hspace=0.3)
        for column in numeric_col:
            axes[i,0].set_title(f'KDE для параметра \n {column}')
            axes[i,1].set_title(f'Boxplot для параметра \n {column}')
            sns.kdeplot(ax = axes[i,0], data=data, x=column, hue=hue)
            sns.boxplot(ax = axes[i,1], data=data, x=column, hue=hue)
            i += 1
    else:
        column = numeric_col[0]
        fig, axes = plt.subplots(1, 2, figsize=(10,4))
        plt.subplots_adjust(hspace=0.3)
        axes[0].set_title(f'KDE для параметра \n {column}')
        axes[1].set_title(f'Boxplot для параметра \n {column}')
        sns.kdeplot(ax = axes[0], data=data, x=column, hue=hue)
        sns.boxplot(ax = axes[1], data=data, x=column, hue=hue)

# %%
def figures_for_category(data, category_col, hue=None):
    if len(category_col) != 1:
        fig, axes = plt.subplots(len(category_col), figsize=(7,len(category_col)*5))
        plt.subplots_adjust(hspace=0.3)
        i = 0
        for column in category_col:
            axes[i].set_title(f'Гистограмма для параметра \n {category_col[i]}')
            ax = sns.countplot(ax = axes[i], data=data, x=column, hue=hue,
                               order=data[column].value_counts(ascending=False).index)
            abs_values = data[column].value_counts(ascending=False).values
            ax.bar_label(container=ax.containers[0], labels=abs_values)
            i += 1
    else:
        column = category_col[0]
        ax = sns.countplot(data=data, x=column, hue=hue,
                           order=data[column].value_counts(ascending=False).index)
        abs_values = data[column].value_counts(ascending=False).values
        ax.bar_label(container=ax.containers[0], labels=abs_values)  
        ax.set_title(f'Гистограмма для параметра \n {column}')

# %% [markdown]
# #### Анализ данных

# %%
all_data.describe().T
# Out:
#                  count                           mean                  min  \
# BeginDate         7043  2017-04-30 13:01:50.918642688  2013-10-01 00:00:00
# MonthlyCharges  7043.0                      64.761692                18.25
# TotalCharges    7043.0                    2115.312885                  0.0
# SeniorCitizen   7043.0                       0.162147                  0.0
#
#                                 25%                  50%                  75%  \
# BeginDate       2015-06-01 00:00:00  2017-09-01 00:00:00  2019-04-01 00:00:00
# MonthlyCharges                 35.5                70.35                89.85
# TotalCharges                 436.75              1343.35              3236.69
# SeniorCitizen                   0.0                  0.0                  0.0
#
#                                 max          std
# BeginDate       2020-02-01 00:00:00          NaN
# MonthlyCharges               118.75    30.090047
# TotalCharges                9221.38  2112.742814
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BeginDate         7043 non-null   datetime64[ns]
#  1   EndDate           7043 non-null   object
#  2   Type              7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   float64
#  7   gender            7043 non-null   object
#  8   SeniorCitizen     7043 non-null   int64
#  9   Partner           7043 non-null   object
#  10  Dependents        7043 non-null   object
#  11  InternetService   5517 non-null   object
#  12  OnlineSecurity    5517 non-null   object
#  13  OnlineBackup      5517 non-null   object
#  14  DeviceProtection  5517 non-null   object
#  15  TechSupport       5517 non-null   object
# ...

# %%
numeric_columns = all_data.select_dtypes('number').columns.drop('SeniorCitizen').to_list()
numeric_columns
# Out:
# ['MonthlyCharges', 'TotalCharges']

# %%
numeric_columns.append('BeginDate')

# %%
display(Markdown(f'<center><b>all_data graphics</b><center>'))
figures_for_num(all_data, numeric_columns)
# Out:
# <center><b>all_data graphics</b><center>

# %%
category_col = all_data.select_dtypes('object').columns
category_col
# Out:
# Index(['EndDate', 'Type', 'PaperlessBilling', 'PaymentMethod', 'gender',
#        'Partner', 'Dependents', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'MultipleLines'],
#       dtype='object')

# %%
figures_for_category(all_data, category_col)

# %% [markdown]
# Целевой параметр - end date. Для него график не получился, так как если нет окончания, то стоит No. Сделаем 2 столбца - один с целевым признаком yes/no,  второй со временем пользования.

# %% [markdown]
# #### Добавление новых признаков

# %%
def calculate_time(row):
    if row['EndDate'] == 'No':
        end_date = pd.to_datetime('2020-02-01')
    else:
        end_date = pd.to_datetime(row['EndDate'])
    days = (end_date - row['BeginDate']).days
    return days

# %%
all_data['usage_days'] = all_data.apply(calculate_time, axis=1)
all_data['usage_days']
# Out:
# customerID
# 7590-VHVEG      31
# 5575-GNVDE    1036
# 3668-QPYBK     123
# 7795-CFOCW    1371
# 9237-HQITU     153
#               ...
# 6840-RESVB     730
# 2234-XADUH    2191
# 4801-JZAZL     337
# 8361-LTMKD     215
# 3186-AJIEK    2010
# Name: usage_days, Length: 7043, dtype: int64

# %%
# all_data['usage_days'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Series name: usage_days
# Non-Null Count  Dtype
# --------------  -----
# 7043 non-null   int64
# dtypes: int64(1)
# memory usage: 368.1+ KB

# %%
all_data['EndDate'] = all_data['EndDate'].apply(lambda x: 'Yes' if x != 'No' else "No")

# %%
all_data.head(3)
# Out:
#             BeginDate EndDate            Type PaperlessBilling  \
# customerID
# 7590-VHVEG 2020-01-01      No  Month-to-month              Yes
# 5575-GNVDE 2017-04-01      No        One year               No
# 3668-QPYBK 2019-10-01      No  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# customerID
# 7590-VHVEG  Electronic check           29.85         31.04  Female
# 5575-GNVDE      Mailed check           56.95       2071.84    Male
# 3668-QPYBK      Mailed check           53.85        226.17    Male
#
#             SeniorCitizen Partner Dependents InternetService OnlineSecurity  \
# customerID
# 7590-VHVEG              0     Yes         No             DSL             No
# 5575-GNVDE              0      No         No             DSL            Yes
# 3668-QPYBK              0      No         No             DSL            Yes
#
#            OnlineBackup DeviceProtection TechSupport StreamingTV  \
# customerID
# ...

# %%
numeric_columns = all_data.select_dtypes('number').columns.drop('SeniorCitizen').to_list()
numeric_columns
# Out:
# ['MonthlyCharges', 'TotalCharges', 'usage_days']

# %%
numeric_columns.append('BeginDate')

# %%
display(Markdown(f'<center><b>all_data graphics</b><center>'))
figures_for_num(all_data, numeric_columns, hue='EndDate')
# Out:
# <center><b>all_data graphics</b><center>

# %%
figures_for_category(all_data, ['EndDate'])

# %%
category_col = all_data.select_dtypes('object').columns
category_col = category_col.drop('EndDate')
category_col
# Out:
# Index(['Type', 'PaperlessBilling', 'PaymentMethod', 'gender', 'Partner',
#        'Dependents', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'MultipleLines'],
#       dtype='object')

# %%
fig, axes = plt.subplots(len(category_col), figsize=(10,len(category_col)*5))
plt.subplots_adjust(hspace=0.3)
i = 0
for column in category_col:
    axes[i].set_title(f'Гистограмма для параметра \n {category_col[i]}')
    ax = sns.histplot(ax = axes[i], data=all_data, x=column, hue='EndDate', stat='percent', common_norm=False)
    i += 1

# %%
data_phik = all_data.copy(deep=True)
data_phik['BeginDate'] = data_phik['BeginDate'].apply(lambda x: pd.to_datetime(x).value)
phik_overview = data_phik.phik_matrix(interval_cols=numeric_columns)
plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'correlation $\phi_K$',
    fontsize_factor=1.5,
    figsize=(20, 15)
)

# %% [markdown]
# На построенных графиках можем наблюдать, что:
# - Те, кто отключился, платили немного больше
# - Распределение количества подключенных дней у абонентов, которые до сих пор платят, имеет 2 пика (около 250 и около 2500), а у тех, кто ушел, пик примерно нна 1000 дней.
# - Уходят больше те, кто платит не за месяц, и автоматическими платежами, а также те, кто с партнером (но тут непонятно, как долго есть партнер, может быть он появился, и два интернета стало не нужна, при этом он мог быть на одном операторе)
# - Также негативно влияет на уход подключенные услуги.
#
# По мматрице корреляции наблюдаем взаимосвязь между датой начала и количеством дней использования, но у даты начала сильная взаимосвязь со всеми параметрами, возможно из-за ее преобразования в секунды. С ключевым признаком наибольшая взаимосвязь с датой начала, днями использования и общими выплатами.

# %% [markdown]
# ### Подготовка данных

# %%
X = all_data.drop(columns=['EndDate', 'BeginDate'])
y = all_data['EndDate'].apply(lambda x: 1 if x == 'Yes' else 0)
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    stratify=y,
                                                    test_size=0.25, random_state=RANDOM_STATE)

# %%
X.head(3)
# Out:
#                       Type PaperlessBilling     PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG  Month-to-month              Yes  Electronic check           29.85
# 5575-GNVDE        One year               No      Mailed check           56.95
# 3668-QPYBK  Month-to-month              Yes      Mailed check           53.85
#
#             TotalCharges  gender  SeniorCitizen Partner Dependents  \
# customerID
# 7590-VHVEG         31.04  Female              0     Yes         No
# 5575-GNVDE       2071.84    Male              0      No         No
# 3668-QPYBK        226.17    Male              0      No         No
#
#            InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# customerID
# 7590-VHVEG             DSL             No          Yes               No
# 5575-GNVDE             DSL            Yes           No              Yes
# 3668-QPYBK             DSL            Yes          Yes               No
#
# ...

# %%
X.columns
# Out:
# Index(['Type', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'MultipleLines',
#        'usage_days'],
#       dtype='object')

# %%
ohe_columns = [
    'Type',
    'PaperlessBilling',
    'PaymentMethod',
    'gender',
    'SeniorCitizen',
    'Partner',
    'Dependents',
    'InternetService',
    'OnlineSecurity',
    'OnlineBackup',
    'DeviceProtection',
    'TechSupport',
    'StreamingTV',
    'StreamingMovies',
    'MultipleLines'
]

ord_columns = []
ord_columns_order = []

num_columns = ['MonthlyCharges',
               'TotalCharges',
               'usage_days'               
]
ohe_pipe = Pipeline(
    [
        (
            'simpleImputer_ohe', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ohe', 
            OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False)
        )
    ]
) 
ord_pipe = Pipeline(
    [
        (
            'simpleImputer_before_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'ord',
            OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=np.nan,
            categories=ord_columns_order
            )
        ),
        (
            'simpleImputer_after_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
) 
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipe, ohe_columns),
        ('ord', ord_pipe, ord_columns),
        ('num', StandardScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %% [markdown]
# ### Обучение моделей

# %%
models = pd.DataFrame(columns=['estimator', 'score'])

# %%
cv_params = {'cv':5,
    'scoring':'roc_auc',
    'n_jobs':-1,
    'verbose':50,
    'error_score':'raise'}

# %% [markdown]
# #### RandomForestClassifier

# %%
pipe = Pipeline(
    [
        ('preprocessor', data_preprocessor),
        ('models', RandomForestClassifier(random_state=RANDOM_STATE))
    ]
)

# %%
param_grid = [{
        'models': [RandomForestClassifier(random_state=RANDOM_STATE, class_weight='balanced')],
        'models__max_depth': [5, 10, 20, None],
        'models__min_samples_split': [2, 3, 4],
        'models__min_samples_leaf': [1, 2, 5, 10, 20]
    }
]

# %%
grid_search_tree = GridSearchCV(
    pipe, 
    param_grid=param_grid,
    **cv_params
)
grid_search_tree.fit(X_train, y_train)
grid_search_tree
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# GridSearchCV(cv=5, error_score='raise',
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe',
#                                                                          Pipeline(steps=[('simpleImputer_ohe',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ohe',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         handle_unknown='ignore',
# ...

# %%
grid_search_tree.best_score_.item()
# Out:
# 0.8194023242179721

# %%
models.loc[0] = ['grid_search_tree', grid_search_tree.best_score_.item()]

# %% [markdown]
# #### SVC

# %%
param_grid = [{
        'models': [SVC(random_state=RANDOM_STATE, class_weight='balanced', probability=True)],
        'models__C': [0.01, 0.1, 0.3, 0.5],
        'models__kernel': ['rbf', 'linear', 'poly', 'sigmoid'],
        'models__degree': [2, 3, 5]
    }
]

# %%
grid_search_SVC = GridSearchCV(
    pipe, 
    param_grid=param_grid,
    **cv_params
)
grid_search_SVC.fit(X_train, y_train)
grid_search_SVC
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=5, error_score='raise',
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('ohe',
#                                                                          Pipeline(steps=[('simpleImputer_ohe',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('ohe',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         handle_unknown='ignore',
# ...

# %%
grid_search_SVC.best_score_.item()
# Out:
# 0.8241412293999923

# %%
models.loc[1] = ['grid_search_SVC', grid_search_SVC.best_score_.item()]

# %% [markdown]
# #### CatBoostClassifier

# %%
X.head(1)
# Out:
#                       Type PaperlessBilling     PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG  Month-to-month              Yes  Electronic check           29.85
#
#             TotalCharges  gender  SeniorCitizen Partner Dependents  \
# customerID
# 7590-VHVEG         31.04  Female              0     Yes         No
#
#            InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# customerID
# 7590-VHVEG             DSL             No          Yes               No
#
#            TechSupport StreamingTV StreamingMovies MultipleLines  usage_days
# customerID
# 7590-VHVEG          No          No              No           NaN          31

# %%
cat_features = ['Type',
                'PaperlessBilling',
                'PaymentMethod',
                'gender',
                'SeniorCitizen',
                'Partner',
                'Dependents',
                'InternetService',
                'OnlineSecurity',
                'OnlineBackup',
                'DeviceProtection',
                'TechSupport',
                'StreamingTV',
                'StreamingMovies',
                'MultipleLines']

# %%
cat_pipe = Pipeline(
    [
        (
            'simpleImputer_cat', 
            SimpleImputer(missing_values=np.nan, strategy='constant', fill_value='No_info')
        )
    ]
) 
data_preprocessor_cat = ColumnTransformer(
    [
        ('cat', cat_pipe, cat_features),
        ('num', StandardScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# %%
pipe_cat = Pipeline(
    [
        ('preprocessor', data_preprocessor_cat),
        ('models', CatBoostClassifier(random_state=RANDOM_STATE))
    ]
)

# %%
data_preprocessor_cat.fit(X_train)
data_preprocessor_cat.get_feature_names_out()
# Out:
# array(['cat__Type', 'cat__PaperlessBilling', 'cat__PaymentMethod',
#        'cat__gender', 'cat__SeniorCitizen', 'cat__Partner',
#        'cat__Dependents', 'cat__InternetService', 'cat__OnlineSecurity',
#        'cat__OnlineBackup', 'cat__DeviceProtection', 'cat__TechSupport',
#        'cat__StreamingTV', 'cat__StreamingMovies', 'cat__MultipleLines',
#        'num__MonthlyCharges', 'num__TotalCharges', 'num__usage_days'],
#       dtype=object)

# %%
param_grid = [{
        'models': [CatBoostClassifier(random_state=RANDOM_STATE,
                                      iterations=100,
                                      cat_features=list(range(0,15)),
                                      verbose=50,
                                     auto_class_weights='Balanced')],
        'models__learning_rate': [0.1, 1, 2],
        'models__depth': [2, 4, 6]
}
]

# %%
grid_search_cat = GridSearchCV(
    pipe_cat, 
    param_grid=param_grid,
    **cv_params
)
grid_search_cat.fit(X_train, y_train)
grid_search_cat
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# 0:	learn: 0.5849015	total: 167ms	remaining: 16.5s
# 50:	learn: 0.3387969	total: 1.83s	remaining: 1.76s
# 99:	learn: 0.2685025	total: 3.45s	remaining: 0us
# GridSearchCV(cv=5, error_score='raise',
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('cat',
#                                                                          Pipeline(steps=[('simpleImputer_cat',
#                                                                                           SimpleImputer(fill_value='No_info',
#                                                                                                         strategy='constant'))]),
#                                                                          ['Type',
# ...

# %%
grid_search_cat.best_score_.item()
# Out:
# 0.8656695228675364

# %%
grid_search_cat.best_estimator_.get_params()
# Out:
# {'memory': None,
#  'steps': [('preprocessor',
#    ColumnTransformer(remainder='passthrough',
#                      transformers=[('cat',
#                                     Pipeline(steps=[('simpleImputer_cat',
#                                                      SimpleImputer(fill_value='No_info',
#                                                                    strategy='constant'))]),
#                                     ['Type', 'PaperlessBilling', 'PaymentMethod',
#                                      'gender', 'SeniorCitizen', 'Partner',
#                                      'Dependents', 'InternetService',
#                                      'OnlineSecurity', 'OnlineBackup',
#                                      'DeviceProtection', 'TechSupport',
#                                      'StreamingTV', 'StreamingMovies',
#                                      'MultipleLines']),
#                                    ('num', StandardScaler(),
# ...

# %% [markdown]
# На основании лучшей модели добавим к ней число итераций, и включим далее в общий список моделей

# %%
param_grid = [{
        'models': [CatBoostClassifier(random_state=RANDOM_STATE,
                                      iterations=500,
                                      cat_features=list(range(0,15)),
                                      verbose=50,
                                     auto_class_weights='Balanced')],
        'models__learning_rate': [1],
        'models__depth': [4]
}
]

# %%
grid_search_cat = GridSearchCV(
    pipe_cat, 
    param_grid=param_grid,
    **cv_params
)
grid_search_cat.fit(X_train, y_train)
grid_search_cat
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 0:	learn: 0.5823493	total: 31.2ms	remaining: 15.6s
# 50:	learn: 0.3015113	total: 1.94s	remaining: 17.1s
# 100:	learn: 0.1783284	total: 3.94s	remaining: 15.6s
# 150:	learn: 0.1251686	total: 5.96s	remaining: 13.8s
# 200:	learn: 0.0916952	total: 7.93s	remaining: 11.8s
# 250:	learn: 0.0696180	total: 9.88s	remaining: 9.81s
# 300:	learn: 0.0555921	total: 11.8s	remaining: 7.81s
# 350:	learn: 0.0438320	total: 13.8s	remaining: 5.84s
# 400:	learn: 0.0365098	total: 15.8s	remaining: 3.9s
# 450:	learn: 0.0301497	total: 17.8s	remaining: 1.93s
# 499:	learn: 0.0259667	total: 19.7s	remaining: 0us
# GridSearchCV(cv=5, error_score='raise',
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('cat',
# ...

# %%
grid_search_cat.best_score_.item()
# Out:
# 0.8739890341835886

# %%
models.loc[2] = ['grid_search_cat', grid_search_cat.best_score_.item()]

# %% [markdown]
# #### LGBMClassifier

# %%
param_grid = [{
        'models': [LGBMClassifier(random_state=RANDOM_STATE, n_estimators=1000, class_weight='balanced', verbose=-1)],
        'models__learning_rate': [0.01, 0.1, 1, 10],
        'models__max_depth': [2, 4, 6],
        'models__num_leaves': [2, 3, 5, 10, 20, 31]
    }
]

# %%
grid_search_lgbm = GridSearchCV(
    pipe, 
    param_grid=param_grid,
    **cv_params
)
grid_search_lgbm.fit(X_train, y_train)
grid_search_lgbm
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# C:\ProgramData\anaconda3\envs\practicum\lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\ProgramData\anaconda3\envs\practicum\lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#   File "C:\ProgramData\anaconda3\envs\practicum\lib\subprocess.py", line 505, in run
#     with Popen(*popenargs, **kwargs) as process:
#   File "C:\ProgramData\anaconda3\envs\practicum\lib\subprocess.py", line 951, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %%
models.loc[0] = ['grid_search_tree', grid_search_tree.best_score_.item()]

# %%
grid_search_lgbm.best_score_.item()
# Out:
# 0.8844323230901014

# %%
models.loc[3] = ['grid_search_lgbm', grid_search_lgbm.best_score_.item()]

# %% [markdown]
# ### Выбор лучшей модели

# %%
models.sort_values(by='score', ascending=False)
# Out:
#           estimator     score
# 3  grid_search_lgbm  0.884432
# 2   grid_search_cat  0.873989
# 1   grid_search_SVC  0.824141
# 0  grid_search_tree  0.819402

# %%
predictions = grid_search_lgbm.predict_proba(X_test)[:, 1]
roc_auc = roc_auc_score(y_test, predictions)
print(f'Ошибка roc_auc на тестовых данных для лучшей модели {roc_auc:.3f}')
# Out:
# Ошибка roc_auc на тестовых данных для лучшей модели 0.908

# %%
feature_importances = pd.Series(grid_search_lgbm.best_estimator_.
                                named_steps['models'].feature_importances_,                                
                                index=grid_search_lgbm.best_estimator_.
                                named_steps['preprocessor'].get_feature_names_out()).sort_values(ascending=False)
sns.barplot(x=feature_importances.values, y=feature_importances.index)
plt.ylabel('features')
# Out:
# Text(0, 0.5, 'features')

# %%
cm = confusion_matrix(y_test, grid_search_lgbm.predict(X_test), normalize='true')
sns.heatmap(cm, annot=True)
plt.ylabel('True labels')
plt.xlabel('Predicted labels')
# Out:
# Text(0.5, 20.049999999999997, 'Predicted labels')

# %%
RocCurveDisplay.from_predictions(y_test, predictions)
plt.plot([0,1], [0,1], linestyle='dashed', label='Random prediction')

# %% [markdown]
# По лучшей модели построены матрица ошибок и ROC-кривая. Также выведено влияния каждого признака на результат предсказания модели, самые важные признаки - цена и сколько времени абонент уже пользуется услугами.

# %%
model = grid_search_lgbm.best_estimator_.named_steps['models']
X_train_lgbm_trans = grid_search_lgbm.best_estimator_.named_steps['preprocessor'].fit_transform(X_train)
X_test_lgbm_trans = grid_search_lgbm.best_estimator_.named_steps['preprocessor'].transform(X_test)
feature_names=grid_search_lgbm.best_estimator_.named_steps['preprocessor'].get_feature_names_out()
explainer = shap.Explainer(model.predict, X_train_lgbm_trans, feature_names=feature_names)
shap_values = explainer(X_test_lgbm_trans)
# Out:
# PermutationExplainer explainer: 1762it [02:47, 10.08it/s]

# %%
shap.plots.beeswarm(shap_values, max_display=20, show=False)
fig, ax = plt.gcf(), plt.gca()
ax.set_title('График SHAP для лучшей модели')
plt.ylabel('Параметры модели')
plt.show()

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# В результате работы были проанализированы полученные данные, на основе которых делается вывод, что:
# - Те, кто отключился, платили немного больше
# - Распределение количества подключенных дней у абонентов, которые до сих пор платят, имеет 2 пика (около 250 и около 2500), а у тех, кто ушел, пик примерно нна 1000 дней.
# - Уходят больше те, кто платит не за месяц, и автоматическими платежами, а также те, кто с партнером (но тут непонятно, как долго есть партнер, может быть он появился, и два интернета стало не нужна, при этом он мог быть на одном операторе)
# - Также негативно влияет на уход подключенные услуги.
# Также по построенной модели и рассмотрению влияния признаков определили, что больше всего влиет время, которое абонент был подключен, а также цена услуг, при этом влияние основных компонентов незначительно.
# Лучшей моделью оказалась LGBMClassifier, ее метрика на тестовых данных 0.91, по ней и была построена диаграмма влияния признаков на целевой.
# На основе этого можно сделать вывод, что необходимо предоставлять акции клиентам, которые подключены довольно долго (больше 500 дней), платят много (возможно имеют кучу подключенных дополнительных услуг, которыми не особо пользуются, из-за чего и меняют связь на подешевле).

# %%
end_time = time.perf_counter()
time_notebook = end_time - start_time
time_notebook
# Out:
# 444.0151262
